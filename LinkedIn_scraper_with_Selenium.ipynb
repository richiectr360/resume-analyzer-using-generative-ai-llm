# %%
import time
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')

# %%
user_input_job_title = input('Enter Job Titles (with comma separated):').split()
print(user_input_job_title)
# Out:
# Enter Job Titles (with comma separated):Python Developer
# ['Python', 'Developer']

# %%
user_input_job_title
# Out:
# ['Python', 'Developer']

# %%
b = []
for i in user_input_job_title:
    x = i.split()
    y = '%20'.join(x)
    b.append(y)

job_title = '%2C%20'.join(b)
print(job_title)
# Out:
# Python%2C%20Developer

# %%
link = f"https://in.linkedin.com/jobs/search?keywords={job_title}&location=India&locationId=&geoId=102713980&f_TPR=r604800&position=1&pageNum=0"
print(link)
# Out:
# https://in.linkedin.com/jobs/search?keywords=Python%2C%20Developer&location=India&locationId=&geoId=102713980&f_TPR=r604800&position=1&pageNum=0

# %%
driver = webdriver.Chrome()
driver.maximize_window()

driver.get(link)
driver.implicitly_wait(10)

# %%
for i in range(0,2):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

    try:
        x = driver.find_element(by=By.CSS_SELECTOR, value="button[aria-label='See more jobs']").click()
        time.sleep(3)
    except:
        pass

# %%
company_name = []

try:
    company = driver.find_elements(by=By.CSS_SELECTOR, value='h4[class="base-search-card__subtitle"]')
    for i in company:
        company_name.append(i.text)

except:
    pass

print(company_name)
# Out:
# ['Technofactorx AI', 'Zithas Technologies', 'Geektrust', 'Bluebix Solutions', 'PloPdo', 'TechLadd', 'Whacked Out ® Media Pte. Ltd.', 'Fusion Plus Solutions Inc', 'Wipro', 'futuremug', 'Razormet Technologies', 'Razormet Technologies', 'Genpact', 'Razormet Technologies', 'Braincuber Technologies', 'HR Aspiration', 'ExpertXai Technologies', 'PloPdo', 'Matrix Marketers', 'Fynd (Shopsense Retail Technologies Ltd.)', 'Fusion Plus Solutions Inc', 'KamalDhari Infotech', 'Birlasoft', 'Rapid Consulting Services', 'Sacumen', 'Ericsson', 'Ericsson', 'Creospan Inc.', 'HTC Global Services', 'LTIMindtree', 'InfraCloud Technologies', 'Virtusa', 'Siemens', 'Element8', 'Capleo Global', 'Innovatily', 'Career One Stop', 'HTC Global Services', 'Tamcherry - Zaportiv', 'hackajob', 'Steady Rabbit', 'ms.tech project service', 'HighPoints Technologies India (P) Ltd', 'EY', 'Universal Software', 'Wasserstoff', 'Pramana', 'marcus evans Group', 'Citi']

# %%
job_title = []

try:
    title = driver.find_elements(by=By.CSS_SELECTOR, value='h3[class="base-search-card__title"]')
    for i in title:
        job_title.append(i.text)

except:
    pass

print(job_title)
# Out:
# ['Python Developer (Fresh Graduate)-', 'Junior Python Developer', 'Python Backend Developer', 'Python Developer', 'Junior Python Developer', 'Python Developer', 'Python Developer', 'Python Developer - Vihaan', 'Python Developer', 'Python Developer Jr', 'Python Developer Trainee/Intern', 'Python Developer Trainee/Intern', 'Python Developer', 'Python Developer Trainee/Intern', 'Python Developer', 'Python Developer', 'Python Developer (2023-24 Batch)', 'Python Developer', 'Python Developer - Django/Flask', 'Backend Python Developer | SDE - 1 / SDE - 2', 'Python developer', 'Python Developer', 'Python Developer', 'Python Developer', 'Python Developer', 'Python Developer', 'Python Developer', 'Python Developer', 'Python Developer', 'Python + R Developer & Machine Learning', 'Python Developer', 'Python Java Developer', 'Python Developer', 'Python Django Developer', 'Python Developer', 'Innovatily - Python Developer - Artificial Intelligence/Machine Learning', 'Python Developer-Contract', 'Python Developer', 'Python Automation Developer', 'Python Developer', 'Artificial Intelligence Engineer - Python Programming', 'Python Developer', 'Python Developer', 'DET_RCE_Python_Developer_GDSF02', 'Python Developer', 'Backend Developer - Python/Java - Internship', 'Software Engineer - Python', 'Python Developer', 'Python Developer - C10']

# %%
company_location = []

try:
    location = driver.find_elements(by=By.CSS_SELECTOR, value='span[class="job-search-card__location"]')
    for i in location:
        company_location.append(i.text)

except:
    pass

print(company_location)
# Out:
# ['India', 'Vadodara, Gujarat, India', 'Bengaluru, Karnataka, India', 'Hyderabad, Telangana, India', 'Noida, Uttar Pradesh, India', 'Pune, Maharashtra, India', 'Hyderabad, Telangana, India', 'Hyderabad, Telangana, India', 'Hyderabad, Telangana, India', 'Kochi, Kerala, India', 'Hubli, Karnataka, India', 'Thiruvananthapuram, Kerala, India', 'Bengaluru, Karnataka, India', 'Guwahati, Assam, India', 'Surat, Gujarat, India', 'Bengaluru, Karnataka, India', 'India', 'Bengaluru, Karnataka, India', 'Chandigarh, Chandigarh, India', 'Mumbai, Maharashtra, India', 'Hyderabad, Telangana, India', 'Surat, Gujarat, India', 'Noida, Uttar Pradesh, India', 'Hyderabad, Telangana, India', 'Mangaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Pune, Maharashtra, India', 'Chennai, Tamil Nadu, India', 'Maharashtra, India', 'India', 'Bangalore Urban, Karnataka, India', 'Chennai, Tamil Nadu, India', 'Kozhikode, Kerala, India', 'Hyderabad, Telangana, India', 'Bengaluru, Karnataka, India', 'India', 'Chennai, Tamil Nadu, India', 'Greater Kolkata Area', 'Chennai, Tamil Nadu, India', 'Greater Kolkata Area', 'India', 'Gurugram, Haryana, India', 'Bengaluru, Karnataka, India', 'Ahmedabad, Gujarat, India', 'Gurugram, Haryana, India', 'Bengaluru, Karnataka, India', 'Mumbai, Maharashtra, India', 'Mumbai, Maharashtra, India']

# %%
job_url = []

try:
    url = driver.find_elements(by=By.XPATH, value='//a[contains(@href, "/jobs/")]')
    for i in url:
        job_url.append(i.get_attribute('href'))

except:
    pass

print(job_url)
# Out:
# ['https://in.linkedin.com/jobs/view/python-developer-fresh-graduate-at-technofactorx-ai-3812624216?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=lp4tMu%2FZcTy0HymQfHbMhw%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/junior-python-developer-at-zithas-technologies-3815795270?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=KmT8R42yPLTyDC24uG9RzQ%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-backend-developer-at-geektrust-3809008239?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=spMWHA3WDC%2FcCaI52L0Y9Q%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-bluebix-solutions-3815118654?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=QYGA5pzaTA2Qt1JttghElA%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/junior-python-developer-at-plopdo-3814680679?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=iX2g09t11vO9E309ggO3WA%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-techladd-3814329365?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=r3IfMnA%2BHn0pgvdRCLow2A%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-whacked-out-%C2%AE-media-pte-ltd-3815119522?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=rHXTD13oM4yR5JrAMv%2BQAA%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-vihaan-at-fusion-plus-solutions-inc-3812004660?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=W6ZFIuHIPJTIWaCc%2FsCX8A%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-wipro-3799070239?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=EpLee3ZGt0%2B9JaeBGuv5nQ%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-jr-at-futuremug-3815797123?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=lPGsFsF%2BqQle2QyU8HqjwQ%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-trainee-intern-at-razormet-technologies-3816488930?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=pVUmx6po%2BW%2F0LRkNiP18xg%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-trainee-intern-at-razormet-technologies-3816489920?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=QAe%2BbFGx1IcW7obssdcvTQ%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-genpact-3811742982?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=MXXoIJxEkxIjO9mA6uJR%2Fw%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-trainee-intern-at-razormet-technologies-3816491703?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=xfpWqGsVlpnHrBE%2BxqKiQw%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-braincuber-technologies-3815117776?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=jnGax6GIvNGiaQZgp2FS%2Fw%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-at-hr-aspiration-3814343226?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=HumC5S9TQBvKQVlZ7IBk4g%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-developer-2023-24-batch-at-expertxai-technologies-3816559628?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=MrFV897SqVCrzetkAs4CzQ%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/python-develop ...

# %%
df = pd.DataFrame(company_name, columns=['Company Name'])
df['Job Title'] = pd.DataFrame(job_title)
df['Location'] = pd.DataFrame(company_location)
df['Website URL'] = pd.DataFrame(job_url)
df
# Out:
#                                  Company Name  \
# 0                            Technofactorx AI
# 1                         Zithas Technologies
# 2                                   Geektrust
# 3                           Bluebix Solutions
# 4                                      PloPdo
# 5                                    TechLadd
# 6               Whacked Out ® Media Pte. Ltd.
# 7                   Fusion Plus Solutions Inc
# 8                                       Wipro
# 9                                   futuremug
# 10                      Razormet Technologies
# 11                      Razormet Technologies
# 12                                    Genpact
# 13                      Razormet Technologies
# 14                    Braincuber Technologies
# 15                              HR Aspiration
# 16                     ExpertXai Technologies
# 17                                     PloPdo
# 18                           Matrix Marketers
# 19  Fynd (Shopsense Retail Technologies Ltd.)
# 20                  Fusion Plus Solutions Inc
# 21                        KamalDhari Infotech
# 22                                  Birlasoft
# 23                  Rapid Consulting Services
# 24                                    Sacumen
# 25                                   Ericsson
# 26                                   Ericsson
# 27                              Creospan Inc.
# 28                        HTC Global Services
# 29                                LTIMindtree
# 30                    InfraCloud Technologies
# 31                                    Virtusa
# 32                                    Siemens
# 33                                   Element8
# 34                              Capleo Global
# 35                                 Innovatily
# 36                            Career One Stop
# 37                        HTC Global Services
# 38                       Tamcherry - Zaportiv
# 39                                   hackajob
# 40                              Steady Rabbit
# 41                    ms.tech project service
# 42      HighPoints Technologies India (P) Ltd
# 43                                         EY
# 44                         Universal Software
# 45                                Wasserstoff
# 46                                    Pramana
# 47                         marcus evans Group
# 48                                       Citi
#
#                                             Job Title  \
# 0                  Python Developer (Fresh Graduate)-
# 1                             Junior Python Developer
# 2                            Python Backend Developer
# 3                                    Python Developer
# 4                             Junior Python Developer
# 5                                    Python Developer
# 6                                    Python Developer
# 7                           Python Developer - Vihaan
# 8                                    Python Developer
# 9                                 Python Developer Jr
# 10                    Python Developer Trainee/Intern
# 11                    Python Developer Trainee/Intern
# 12                                   Python Developer
# 13                    Python Developer Trainee/Intern
# 14                                   Python Developer
# 15                                   Python Developer
# 16                   Python Developer (2023-24 Batch)
# 17                                   Python Developer
# 18                    Python Developer - Django/Flask
# 19       Backend Python Developer | SDE - 1 / SDE - 2
# 20                                   Python developer
# 21                                   Python Developer
# 22                                   Python Developer
# 23                                   Python Developer
# 24                                   Python Developer
# 25                                   Python Developer
# 26                                   Python Developer
# 27                                   Python Developer
# 28                                   Python Developer
# 29            Python + R Developer & Machine Learning
# 30                                   Python Developer
# 31                              Python Java Developer
# 32                                   Python Developer
# 33                            Python Django Developer
# 34                                   Python Developer
# 35  Innovatily - Python Developer - Artificial Int...
# 36                          Python Developer-Contract
# 37                                   Python Developer
# 38                        Python Automation Developer
# 39                                   Python Developer
# 40  Artificial Intelligence Engineer - Python Prog...
# 41                                   Python Developer
# 42                                   Python Developer
# 43                    DET_RCE_Python_Developer_GDSF02
# 44                                   Python Developer
# 45       Backend Developer - Python/Java - Internship
# 46                         Software Engineer - Python
# 47                                   Python Developer
# 48                             Python Developer - C10
#
#                              Location  \
# 0                               India
# 1            Vadodara, Gujarat, India
# 2         Bengaluru, Karnataka, India
# 3         Hyderabad, Telangana, India
# 4         Noida, Uttar Pradesh, India
# 5            Pune, Maharashtra, India
# 6         Hyderabad, Telangana, India
# 7         Hyderabad, Telangana, India
# 8         Hyderabad, Telangana, India
# 9                Kochi, Kerala, India
# 10            Hubli, Karnataka, India
# 11  Thiruvananthapuram, Kerala, India
# 12        Bengaluru, Karnataka, India
# 13             Guwahati, Assam, India
# 14              Surat, Gujarat, India
# 15        Bengaluru, Karnataka, India
# 16                              India
# 17        Bengaluru, Karnataka, India
# 18      Chandigarh, Chandigarh, India
# 19         Mumbai, Maharashtra, India
# 20        Hyderabad, Telangana, India
# 21              Surat, Gujarat, India
# 22        Noida, Uttar Pradesh, India
# 23        Hyderabad, Telangana, India
# 24        Mangaluru, Karnataka, India
# 25        Bengaluru, Karnataka, India
# 26        Bengaluru, Karnataka, India
# 27           Pune, Maharashtra, India
# 28         Chennai, Tamil Nadu, India
# 29                 Maharashtra, India
# 30                              India
# 31  Bangalore Urban, Karnataka, India
# 32         Chennai, Tamil Nadu, India
# 33           Kozhikode, Kerala, India
# 34        Hyderabad, Telangana, India
# 35        Bengaluru, Karnataka, India
# 36                              India
# 37         Chennai, Tamil Nadu, India
# 38               Greater Kolkata Area
# 39         Chennai, Tamil Nadu, India
# 40               Greater Kolkata Area
# 41                              India
# 42           Gurugram, Haryana, India
# 43        Bengaluru, Karnataka, India
# 44          Ahmedabad, Gujarat, India
# 45           Gurugram, Haryana, India
# 46        Bengaluru, Karnataka, India
# 47         Mumbai, Maharashtra, India
# 48         Mumbai, Maharashtra, India
#
#                                           Website URL
# 0   https://in.linkedin.com/jobs/view/python-devel...
# 1   https://in.linkedin.com/jobs/view/junior-pytho...
# 2   https://in.linkedin.com/jobs/view/python-backe...
# 3   https://in.linkedin.com/jobs/view/python-devel...
# 4   https://in.linkedin.com/jobs/view/junior-pytho...
# 5   https://in.linkedin.com/jobs/view/python-devel...
# 6   https://in.linkedin.com/jobs/view/python-devel...
# 7   https://in.linkedin.com/jobs/view/python-devel...
# 8   https://in.linkedin.com/jobs/view/python-devel...
# 9   https://in.linkedin.com/jobs/view/python-devel...
# 10  https://in.linkedin.com/jobs/view/python-devel...
# 11  https://in.linkedin.com/jobs/view/python-devel...
# 12  https://in.linkedin.com/jobs/view/python-devel...
# 13  https://in.linkedin.com/jobs/view/python-devel...
# 14  https://in.linkedin.com/jobs/view/python-devel...
# 15  https://in.linkedin.com/jobs/view/python-devel...
# 16  https://in.linkedin.com/jobs/view/python-devel...
# 17  https://in.linkedin.com/jobs/view/python-devel...
# 18  https://in.linkedin.com/jobs/view/python-devel...
# 19  https://in.linkedin.com/jobs/view/backend-pyth...
# 20  https://in.linkedin.com/jobs/view/python-devel...
# 21  https://in.linkedin.com/jobs/view/python-devel...
# 22  https://in.linkedin.com/jobs/view/python-devel...
# 23  https://in.linkedin.com/jobs/view/python-devel...
# 24  https://in.linkedin.com/jobs/view/python-devel...
# 25  https://in.linkedin.com/jobs/view/python-devel...
# 26  https://in.linkedin.com/jobs/view/python-devel...
# 27  https://in.linkedin.com/jobs/view/python-devel...
# 28  https://in.linkedin.com/jobs/view/python-devel...
# 29  https://in.linkedin.com/jobs/view/python-%2B-r...
# 30  https://in.linkedin.com/jobs/view/python-devel...
# 31  https://in.linkedin.com/jobs/view/python-java-...
# 32  https://in.linkedin.com/jobs/view/python-devel...
# 33  https://in.linkedin.com/jobs/view/python-djang...
# 34  https://in.linkedin.com/jobs/view/python-devel...
# 35  https://in.linkedin.com/jobs/view/innovatily-p...
# 36  https://in.linkedin.com/jobs/view/python-devel...
# 37  https://in.linkedin.com/jobs/view/python-devel...
# 38  https://in.linkedin.com/jobs/view/python-autom...
# 39  https://in.linkedin.com/jobs/view/python-devel...
# 40  https://in.linkedin.com/jobs/view/artificial-i...
# 41  https://in.linkedin.com/jobs/view/python-devel...
# 42  https://in.linkedin.com/jobs/view/python-devel...
# 43  https://in.linkedin.com/jobs/view/det-rce-pyth...
# 44  https://in.linkedin.com/jobs/view/python-devel...
# 45  https://in.linkedin.com/jobs/view/backend-deve...
# 46  https://in.linkedin.com/jobs/view/software-eng...
# 47  https://in.linkedin.com/jobs/view/python-devel...
# 48  https://in.linkedin.com/jobs/view/python-devel...

# %%
df.to_csv('python_developer.csv')

# %%
def job_title_filter(x, user_input_job_title):
    
    s = [i.lower() for i in user_input_job_title]
    suggestion = []
    for i in s:
        suggestion.extend(i.split())

    s = x.split()
    a = [i.lower() for i in s]
    
    intersection = list(set(suggestion).intersection(set(a)))
    return x if len(intersection)>1 else np.nan

# %%
df['Job Title'] = df['Job Title'].apply(lambda x: job_title_filter(x, user_input_job_title))
df=df.dropna()
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                  Company Name  \
# 0                            Technofactorx AI
# 1                         Zithas Technologies
# 2                                   Geektrust
# 3                           Bluebix Solutions
# 4                                      PloPdo
# 5                                    TechLadd
# 6               Whacked Out ® Media Pte. Ltd.
# 7                   Fusion Plus Solutions Inc
# 8                                       Wipro
# 9                                   futuremug
# 10                      Razormet Technologies
# 11                      Razormet Technologies
# 12                                    Genpact
# 13                      Razormet Technologies
# 14                    Braincuber Technologies
# 15                              HR Aspiration
# 16                     ExpertXai Technologies
# 17                                     PloPdo
# 18                           Matrix Marketers
# 19  Fynd (Shopsense Retail Technologies Ltd.)
# 20                  Fusion Plus Solutions Inc
# 21                        KamalDhari Infotech
# 22                                  Birlasoft
# 23                  Rapid Consulting Services
# 24                                    Sacumen
# 25                                   Ericsson
# 26                                   Ericsson
# 27                              Creospan Inc.
# 28                        HTC Global Services
# 29                                LTIMindtree
# 30                    InfraCloud Technologies
# 31                                    Virtusa
# 32                                    Siemens
# 33                                   Element8
# 34                              Capleo Global
# 35                                 Innovatily
# 36                        HTC Global Services
# 37                       Tamcherry - Zaportiv
# 38                                   hackajob
# 39                    ms.tech project service
# 40      HighPoints Technologies India (P) Ltd
# 41                         Universal Software
# 42                         marcus evans Group
# 43                                       Citi
#
#                                             Job Title  \
# 0                  Python Developer (Fresh Graduate)-
# 1                             Junior Python Developer
# 2                            Python Backend Developer
# 3                                    Python Developer
# 4                             Junior Python Developer
# 5                                    Python Developer
# 6                                    Python Developer
# 7                           Python Developer - Vihaan
# 8                                    Python Developer
# 9                                 Python Developer Jr
# 10                    Python Developer Trainee/Intern
# 11                    Python Developer Trainee/Intern
# 12                                   Python Developer
# 13                    Python Developer Trainee/Intern
# 14                                   Python Developer
# 15                                   Python Developer
# 16                   Python Developer (2023-24 Batch)
# 17                                   Python Developer
# 18                    Python Developer - Django/Flask
# 19       Backend Python Developer | SDE - 1 / SDE - 2
# 20                                   Python developer
# 21                                   Python Developer
# 22                                   Python Developer
# 23                                   Python Developer
# 24                                   Python Developer
# 25                                   Python Developer
# 26                                   Python Developer
# 27                                   Python Developer
# 28                                   Python Developer
# 29            Python + R Developer & Machine Learning
# 30                                   Python Developer
# 31                              Python Java Developer
# 32                                   Python Developer
# 33                            Python Django Developer
# 34                                   Python Developer
# 35  Innovatily - Python Developer - Artificial Int...
# 36                                   Python Developer
# 37                        Python Automation Developer
# 38                                   Python Developer
# 39                                   Python Developer
# 40                                   Python Developer
# 41                                   Python Developer
# 42                                   Python Developer
# 43                             Python Developer - C10
#
#                              Location  \
# 0                               India
# 1            Vadodara, Gujarat, India
# 2         Bengaluru, Karnataka, India
# 3         Hyderabad, Telangana, India
# 4         Noida, Uttar Pradesh, India
# 5            Pune, Maharashtra, India
# 6         Hyderabad, Telangana, India
# 7         Hyderabad, Telangana, India
# 8         Hyderabad, Telangana, India
# 9                Kochi, Kerala, India
# 10            Hubli, Karnataka, India
# 11  Thiruvananthapuram, Kerala, India
# 12        Bengaluru, Karnataka, India
# 13             Guwahati, Assam, India
# 14              Surat, Gujarat, India
# 15        Bengaluru, Karnataka, India
# 16                              India
# 17        Bengaluru, Karnataka, India
# 18      Chandigarh, Chandigarh, India
# 19         Mumbai, Maharashtra, India
# 20        Hyderabad, Telangana, India
# 21              Surat, Gujarat, India
# 22        Noida, Uttar Pradesh, India
# 23        Hyderabad, Telangana, India
# 24        Mangaluru, Karnataka, India
# 25        Bengaluru, Karnataka, India
# 26        Bengaluru, Karnataka, India
# 27           Pune, Maharashtra, India
# 28         Chennai, Tamil Nadu, India
# 29                 Maharashtra, India
# 30                              India
# 31  Bangalore Urban, Karnataka, India
# 32         Chennai, Tamil Nadu, India
# 33           Kozhikode, Kerala, India
# 34        Hyderabad, Telangana, India
# 35        Bengaluru, Karnataka, India
# 36         Chennai, Tamil Nadu, India
# 37               Greater Kolkata Area
# 38         Chennai, Tamil Nadu, India
# 39                              India
# 40           Gurugram, Haryana, India
# 41          Ahmedabad, Gujarat, India
# 42         Mumbai, Maharashtra, India
# 43         Mumbai, Maharashtra, India
#
#                                           Website URL
# 0   https://in.linkedin.com/jobs/view/python-devel...
# 1   https://in.linkedin.com/jobs/view/junior-pytho...
# 2   https://in.linkedin.com/jobs/view/python-backe...
# 3   https://in.linkedin.com/jobs/view/python-devel...
# 4   https://in.linkedin.com/jobs/view/junior-pytho...
# 5   https://in.linkedin.com/jobs/view/python-devel...
# 6   https://in.linkedin.com/jobs/view/python-devel...
# 7   https://in.linkedin.com/jobs/view/python-devel...
# 8   https://in.linkedin.com/jobs/view/python-devel...
# 9   https://in.linkedin.com/jobs/view/python-devel...
# 10  https://in.linkedin.com/jobs/view/python-devel...
# 11  https://in.linkedin.com/jobs/view/python-devel...
# 12  https://in.linkedin.com/jobs/view/python-devel...
# 13  https://in.linkedin.com/jobs/view/python-devel...
# 14  https://in.linkedin.com/jobs/view/python-devel...
# 15  https://in.linkedin.com/jobs/view/python-devel...
# 16  https://in.linkedin.com/jobs/view/python-devel...
# 17  https://in.linkedin.com/jobs/view/python-devel...
# 18  https://in.linkedin.com/jobs/view/python-devel...
# 19  https://in.linkedin.com/jobs/view/backend-pyth...
# 20  https://in.linkedin.com/jobs/view/python-devel...
# 21  https://in.linkedin.com/jobs/view/python-devel...
# 22  https://in.linkedin.com/jobs/view/python-devel...
# 23  https://in.linkedin.com/jobs/view/python-devel...
# 24  https://in.linkedin.com/jobs/view/python-devel...
# 25  https://in.linkedin.com/jobs/view/python-devel...
# 26  https://in.linkedin.com/jobs/view/python-devel...
# 27  https://in.linkedin.com/jobs/view/python-devel...
# 28  https://in.linkedin.com/jobs/view/python-devel...
# 29  https://in.linkedin.com/jobs/view/python-%2B-r...
# 30  https://in.linkedin.com/jobs/view/python-devel...
# 31  https://in.linkedin.com/jobs/view/python-java-...
# 32  https://in.linkedin.com/jobs/view/python-devel...
# 33  https://in.linkedin.com/jobs/view/python-djang...
# 34  https://in.linkedin.com/jobs/view/python-devel...
# 35  https://in.linkedin.com/jobs/view/innovatily-p...
# 36  https://in.linkedin.com/jobs/view/python-devel...
# 37  https://in.linkedin.com/jobs/view/python-autom...
# 38  https://in.linkedin.com/jobs/view/python-devel...
# 39  https://in.linkedin.com/jobs/view/python-devel...
# 40  https://in.linkedin.com/jobs/view/python-devel...
# 41  https://in.linkedin.com/jobs/view/python-devel...
# 42  https://in.linkedin.com/jobs/view/python-devel...
# 43  https://in.linkedin.com/jobs/view/python-devel...

# %%
df=df.iloc[:10,:]
df
# Out:
#                     Company Name                           Job Title  \
# 0               Technofactorx AI  Python Developer (Fresh Graduate)-
# 1            Zithas Technologies             Junior Python Developer
# 2                      Geektrust            Python Backend Developer
# 3              Bluebix Solutions                    Python Developer
# 4                         PloPdo             Junior Python Developer
# 5                       TechLadd                    Python Developer
# 6  Whacked Out ® Media Pte. Ltd.                    Python Developer
# 7      Fusion Plus Solutions Inc           Python Developer - Vihaan
# 8                          Wipro                    Python Developer
# 9                      futuremug                 Python Developer Jr
#
#                       Location  \
# 0                        India
# 1     Vadodara, Gujarat, India
# 2  Bengaluru, Karnataka, India
# 3  Hyderabad, Telangana, India
# 4  Noida, Uttar Pradesh, India
# 5     Pune, Maharashtra, India
# 6  Hyderabad, Telangana, India
# 7  Hyderabad, Telangana, India
# 8  Hyderabad, Telangana, India
# 9         Kochi, Kerala, India
#
#                                          Website URL
# 0  https://in.linkedin.com/jobs/view/python-devel...
# 1  https://in.linkedin.com/jobs/view/junior-pytho...
# 2  https://in.linkedin.com/jobs/view/python-backe...
# 3  https://in.linkedin.com/jobs/view/python-devel...
# 4  https://in.linkedin.com/jobs/view/junior-pytho...
# 5  https://in.linkedin.com/jobs/view/python-devel...
# 6  https://in.linkedin.com/jobs/view/python-devel...
# 7  https://in.linkedin.com/jobs/view/python-devel...
# 8  https://in.linkedin.com/jobs/view/python-devel...
# 9  https://in.linkedin.com/jobs/view/python-devel...

# %%
def description(link):

    driver.get(link)
    time.sleep(3)

    driver.find_element(by=By.CSS_SELECTOR, value='button[data-tracking-control-name="public_jobs_show-more-html-btn"]').click()
    time.sleep(2)

    description = driver.find_elements(by=By.CSS_SELECTOR, value='div[class="show-more-less-html__markup relative overflow-hidden"]')
    driver.implicitly_wait(4)
    
    for j in description:
        return j.text

# %%
website_url = df['Website URL'].tolist()

job_description = []

for i in website_url:
    data = description(i)
    if data is not None and len(data.strip()) > 0:
        job_description.append(data)
    else:
        job_description.append('Description Not Available')

# %%
df['Job Description'] = pd.DataFrame(job_description, columns=['Description'])
df
# Out:
#                     Company Name                           Job Title  \
# 0               Technofactorx AI  Python Developer (Fresh Graduate)-
# 1            Zithas Technologies             Junior Python Developer
# 2                      Geektrust            Python Backend Developer
# 3              Bluebix Solutions                    Python Developer
# 4                         PloPdo             Junior Python Developer
# 5                       TechLadd                    Python Developer
# 6  Whacked Out ® Media Pte. Ltd.                    Python Developer
# 7      Fusion Plus Solutions Inc           Python Developer - Vihaan
# 8                          Wipro                    Python Developer
# 9                      futuremug                 Python Developer Jr
#
#                       Location  \
# 0                        India
# 1     Vadodara, Gujarat, India
# 2  Bengaluru, Karnataka, India
# 3  Hyderabad, Telangana, India
# 4  Noida, Uttar Pradesh, India
# 5     Pune, Maharashtra, India
# 6  Hyderabad, Telangana, India
# 7  Hyderabad, Telangana, India
# 8  Hyderabad, Telangana, India
# 9         Kochi, Kerala, India
#
#                                          Website URL  \
# 0  https://in.linkedin.com/jobs/view/python-devel...
# 1  https://in.linkedin.com/jobs/view/junior-pytho...
# 2  https://in.linkedin.com/jobs/view/python-backe...
# 3  https://in.linkedin.com/jobs/view/python-devel...
# 4  https://in.linkedin.com/jobs/view/junior-pytho...
# 5  https://in.linkedin.com/jobs/view/python-devel...
# 6  https://in.linkedin.com/jobs/view/python-devel...
# 7  https://in.linkedin.com/jobs/view/python-devel...
# 8  https://in.linkedin.com/jobs/view/python-devel...
# 9  https://in.linkedin.com/jobs/view/python-devel...
#
#                                      Job Description
# 0  Overview\n\nAs a Fresher Python Developer, you...
# 1  Company Overview\n\nZithas Technologies is an ...
# 2  Job Description\n\nCompany Name : Siemens Adva...
# 3  Job Title: Python Developer with Node.js Exper...
# 4  Responsibilities:\n1) Work closely with produc...
# 5  Overview\n\nThe Python Developer plays a cruci...
# 6  Writing and testing code using programming lan...
# 7  Location: any infosys office in India\n\nMust ...
# 8  Role Purpose\n\nThe purpose of this role is to...
# 9  Job Description\n\nRole: : Python Developer\n\...

# %%
l = len(df['Company Name'])
for i in range(0,l):
    print(f"Company Name : {df.iloc[i,0]}")
    print(f"Job Title    : {df.iloc[i,1]}")
    print(f"Location     : {df.iloc[i,2]}")
    print(f"Website URL  : {df.iloc[i,3]}")
    print(f"Description  : {df.iloc[i,4]}")
# Out:
# Company Name : Technofactorx AI
# Job Title    : Python Developer (Fresh Graduate)-
# Location     : India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-fresh-graduate-at-technofactorx-ai-3812624216?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=lp4tMu%2FZcTy0HymQfHbMhw%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Overview
#
# As a Fresher Python Developer, you will play a crucial role in our development team, focusing on building and implementing functional programs. You will have the opportunity to work on various projects, collaborating with cross-functional teams to deliver high-quality software solutions.
#
# Key Responsibilities
#
# Write clean, efficient, and well-documented code using Python programming language.
# Collaborate with team members to understand project requirements and deliver scalable software solutions.
# Participate in the design and implementation of applications, incorporating user feedback for continuous improvement.
# Conduct thorough testing and debugging of applications to ensure high performance and reliability.
# Assist in the integration of user-facing elements with server-side logic.
# Learn and apply best practices in software development and maintain up-to-date knowledge of technology trends.
# Work on data analysis and visualization tasks using Python libraries.
# Contribute to the optimization of existing code and identify areas for improvement.
# Document development processes, code, and solutions for future reference.
# Participate in code reviews and provide constructive feedback to peers.
#
# Required Qualifications
#
# Bachelor’s or Master’s degree in Computer Science, Engineering, or a related field.
# Proficiency in Python programming language and understanding of its core principles.
# Strong problem-solving skills with the ability to analyze and resolve complex issues.
# Knowledge of data structures, algorithms, and software development patterns.
# Experience with version control systems such as Git.
# Understanding of SQL and database management systems.
# Ability to work effectively in a collaborative team environment.
# Excellent communication skills and the ability to convey technical concepts clearly.
# Passion for learning new technologies and adapting to industry trends.
# Previous internship or project experience in Python development is a plus.
# Proactive attitude towards seeking guidance and continuous self-improvement.
# Understanding of web development concepts including HTML, CSS, and JavaScript is preferred.
# Knowledge of software testing methodologies and tools is a bonus.
#
# Skills: python,teamwork,communication,software development,debugging
# Company Name : Zithas Technologies
# Job Title    : Junior Python Developer
# Location     : Vadodara, Gujarat, India
# Website URL  : https://in.linkedin.com/jobs/view/junior-python-developer-at-zithas-technologies-3815795270?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=KmT8R42yPLTyDC24uG9RzQ%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Company Overview
#
# Zithas Technologies is an IT solutions provider that helps businesses flourish in the market. With a team of professionals holding expertise in various fields, we strive to deliver the best solutions for our clients' business-related problems. We have 11-50 employees and our headquarters are located in Vadodara, Gujarat. Visit our website at www.zithas.com for more information.
#
# Job Overview
#
# We are seeking a Junior Python Developer to join our team at Zithas Technologies. As a Junior Python Developer, you will be responsible for developing high-quality software solutions using Python programming language. This is a full-time position based in Vadodara, Gujarat, India. The ideal candidate should have 1 to 3 years of experience in Python development.
#
# Qualifications And Skills
#
# 1 to 3 years of experience in Python development
# Strong knowledge of Artificial Intelligence (AI) and Machine Learning
# Proficient in Python programming language
# Experience with Odoo is a plus
# Excellent communication skills
# Good understanding of industry trends and developments
#
# Roles And Responsibilities
#
# Develop and maintain software applications using Python programming language
# Collaborate with cross-functional teams to define, design, and ship new features
# Write clean and efficient code
# Troubleshoot and debug issues
# Optimize performance and scalability of the applications
# Ensure code quality and adhere to best practices
# Stay up-to-date with industry trends and advancements in Python development
# Company Name : Geektrust
# Job Title    : Python Backend Developer
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/python-backend-developer-at-geektrust-3809008239?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=spMWHA3WDC%2FcCaI52L0Y9Q%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Job Description
#
# Company Name : Siemens Advanta DTS
#
# Job Description
#
# We are looking for a python expert who has proven 5+ years of experience in automating solutions on Linux development environments.
#
# You should be capable of developing python-based automation solutions or analytic solutions that can be used to improve reporting and data visualization solutions.
#
# Required Skills
#
# Solid experience in Python back-end development
# Demonstrated Experience on API Development in an AWS environment.
# Demonstrated Knowledge on API Security Concepts and their implementation.
# Knowledge on Data Engineering Concepts with focus on SQL-type querying
# Strong understanding of software design patterns and testing principles
# Experience with Docker, Kubernetes and Terraform is a plus.
# Experience with component-based web frameworks such as React or Vue.js is a plus.
# Understanding of ETL processes to extract data from different data sources is a plus.
# Knowledge on fundamental data analytics concepts is a plus good knowledge in interacting with database systems (SQL, NoSQL) and webservices (REST)
# Experienced in establishing an optimized CI / CD environment relevant to the project.
# Good knowledge on repository management tools like Git, Bit Bucket, etc.
# Excellent debugging skills/strategies.
# Excellent communication skills
# Experienced in working in an Agile environment.
#
# Nice To Have
#
# Good Knowledge in eclipse IDE, developed add-ons/ plugins on eclipse Platform.
# Knowledge of 93K Semiconductor test platforms
# Good know-how of agile management tools like Jira, Azure DevOps.
# Good knowledge of RHEL
# Knowledge of JIRA administration
#
# (ref:hirist.com)
# Company Name : Bluebix Solutions
# Job Title    : Python Developer
# Location     : Hyderabad, Telangana, India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-at-bluebix-solutions-3815118654?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=QYGA5pzaTA2Qt1JttghElA%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Job Title: Python Developer with Node.js Experience for AI-Integrated ATS Projects
#
# Job Description
#
# We are seeking a talented and experienced Python Developer with a strong background in Node.js to join our team. As a key member of our development team, you will be responsible for working on internal projects that involve integrating AI features with our Applicant Tracking System (ATS). The ideal candidate will have a solid understanding of both Python and Node.js, with a proven track record of successfully delivering projects in AI-integrated environments.
#
# Responsibilities
#
# AI Integration with ATS:
#
# Collaborate with cross-functional teams to understand AI requirements and integrate advanced features into our Applicant Tracking System.
# Work on enhancing the system's capabilities through the seamless integration of AI technologies.
#
# Python And Node.js Development
#
# Design, develop, and maintain Python and Node.js applications to support various aspects of the project.
# Write clean, efficient, and well-documented code that meets industry standards.
#
# API Development And Integration
#
# Create and maintain RESTful APIs for communication between different components of the system.
# Integrate third-party APIs and services as needed for project requirements.
#
# Database Management
#
# Work with databases (SQL and/or NoSQL) to manage and organize data related to the ATS and AI features.
# Optimize database queries for improved performance.
#
# Collaboration And Communication
#
# Collaborate with internal teams, including product managers, designers, and other developers, to deliver high-quality solutions.
# Communicate effectively with stakeholders to understand project requirements and provide regular updates on progress.
#
# Testing And Quality Assurance
#
# Write unit tests and participate in code reviews to maintain code quality and reliability.
# Conduct testing to identify and fix bugs, ensuring the robustness of the developed features.
#
# Documentation
#
# Create and maintain technical documentation for code, APIs, and integrations.
# Provide documentation to support knowledge transfer within the development team.
#
# Continuous Learning
#
# Stay up-to-date with industry trends and advancements in AI, Python, and Node.js.
# Share knowledge and best practices with the team to foster a culture of continuous improvement.
#
# Requirements
#
# Proven experience as a Python Developer with expertise in Node.js development.
# Previous involvement in AI-integrated projects, specifically working with Applicant Tracking Systems, is highly desirable.
# Strong knowledge of database systems (SQL and/or NoSQL).
# Familiarity with RESTful API development and integration.
# Solid understanding of software development principles and best practices.
# Excellent collaboration and communication skills.
# Ability to work in a fast-paced environment and deliver high-quality solutions on time.
#
# If you are passionate about cutting-edge technologies, thrive in a collaborative environment, and have a strong background in Python, Node.js, and AI integration, we would love to hear from you. Join our team and contribute to the evolution of our AI-integrated Applicant Tracking System.
# Company Name : PloPdo
# Job Title    : Junior Python Developer
# Location     : Noida, Uttar Pradesh, India
# Website URL  : https://in.linkedin.com/jobs/view/junior-python-developer-at-plopdo-3814680679?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=iX2g09t11vO9E309ggO3WA%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Responsibilities:
# 1) Work closely with product, project and business teams to translate user feedback and company vision into technical roadmap.
# 2) Closely working with different teams to conceptualize, design, and build highly scalable and reliable software solutions with REST APIs following SDLC best practices.
# 3) Design & Implementation of product requirements in a timely manner following coding best practices & high-quality coding standards.
# 4) Coordinate with global multi-location teams
#
# Requirement:
# 1) BS/MS in Computer Science or relevant field and experience in building backend services with Python using Django >= 2.1.3, Django REST framework >= 3.1, and Flask.
# 2) 2+ years of experience with Web Application technologies: REST API, MongoDB, MySQL, AWS services (S3, EC2, RDS, Lambda, API Gateway, …), CI/CD pipeline, and Apache/Nginx web servers.
# 3) Experience in building web applications using JavaScript, react would be an added advantage.
# Company Name : TechLadd
# Job Title    : Python Developer
# Location     : Pune, Maharashtra, India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-at-techladd-3814329365?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=r3IfMnA%2BHn0pgvdRCLow2A%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Overview
#
# The Python Developer plays a crucial role in our organization by developing and maintaining high-quality web applications using Python and related frameworks. They will collaborate with cross-functional teams to design and implement innovative solutions that meet the needs of our clients and contribute to the overall success of the company.
#
# Key Responsibilities
#
# Participate in the entire application lifecycle, focusing on coding and debugging
# Write effective, scalable code
# Develop back-end components to improve responsiveness and overall performance
# Integrate user-facing elements into applications
# Test and debug programs
# Improve functionality of existing systems
# Implement security and data protection
# Design and implement low-latency, high-availability, and performance applications
# Create and maintain databases
# Stay informed about industry best practices
# Conduct software analysis, programming, testing, and debugging
# Document development phases and monitor systems
# Develop and deploy server-side logic
# Work with front-end developers and UI/UX designers
# Build reusable code and libraries for future use
#
# Required Qualifications
#
# Bachelor's degree in Computer Science, Engineering, or a related field
# Proven experience as a Python Developer or similar role
# Experience with web frameworks such as Django, Flask, etc.
# Proficiency in using relational databases (e.g., PostgreSQL, MySQL) and NoSQL databases
# Strong understanding of server-side templating languages such as Jinja 2
# Good understanding of front-end technologies, such as JavaScript, HTML5, and CSS3
# Understanding of RESTful APIs and experience building and consuming them
# Knowledge of user authentication and authorization between multiple systems, servers, and environments
# Basic understanding of accessibility and security compliance
# Knowledge of version control systems (e.g., Git)
# Familiarity with event-driven programming in Python
# Excellent analytical and problem-solving skills
# Strong unit test and debugging skills
# Good communication and teamwork skills
# Ability to work in an Agile environment
#
# Skills: python,django,sql,agile,databases
# Company Name : Whacked Out ® Media Pte. Ltd.
# Job Title    : Python Developer
# Location     : Hyderabad, Telangana, India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-at-whacked-out-%C2%AE-media-pte-ltd-3815119522?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=rHXTD13oM4yR5JrAMv%2BQAA%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Writing and testing code using programming languages such as, Python, JavaScript
# Collaborating with senior developers and other team members to design, develop, and maintain software applications
# Debugging and troubleshooting code to identify and fix issues
# Learning new programming languages, frameworks, and tools as needed
# Participating in code reviews and providing feedback to improve code quality
# Documenting code and development processes to ensure knowledge transfer and maintainability
# Contributing to the development of software development best practices and standards
# Staying up-to-date with industry trends and emerging technologies
#
# Should have a solid foundation in computer science principles, data structures, algorithms, and programming languages. Additionally, a junior developer should have good analytical, problem-solving, and communication skills to effectively collaborate with other team members and stakeholders. A willingness to learn, adapt, and continuously improve is also important.
# Company Name : Fusion Plus Solutions Inc
# Job Title    : Python Developer - Vihaan
# Location     : Hyderabad, Telangana, India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-vihaan-at-fusion-plus-solutions-inc-3812004660?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=W6ZFIuHIPJTIWaCc%2FsCX8A%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Location: any infosys office in India
#
# Must Have: Python
#
# Nice to have: AWS with Lambda
# Company Name : Wipro
# Job Title    : Python Developer
# Location     : Hyderabad, Telangana, India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-at-wipro-3799070239?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=EpLee3ZGt0%2B9JaeBGuv5nQ%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Role Purpose
#
# The purpose of this role is to design, test and maintain softwareprograms for operating systems or applications which needs to bedeployed at a client end and ensure its meet 100% quality assuranceparameters
#
# Do
#
# Instrumental in understanding the requirements and design ofthe product/ software
# Develop software solutions by studying information needs,studying systems flow, data usage and work processes
# Investigating problem areas followed by the software developmentlife cycle
# Facilitate root cause analysis of the system issues and problemstatement
# Identify ideas to improve system performance and impactavailability
# Analyze client requirements and convert requirements to feasibledesign
# Collaborate with functional teams or systems analysts who carryout the detailed investigation into software requirements
# Conferring with project managers to obtain information onsoftware capabilities
# Perform coding and ensure optimal software/ moduledevelopment
# Determine operational feasibility by evaluating analysis,problem definition, requirements, software development and proposedsoftware
# Develop and automate processes for software validation by setting up and designing test cases/scenarios/usage cases, andexecuting these cases
# Modifying software to fix errors, adapt it to new hardware,improve its performance, or upgrade interfaces.
# Analyzing information to recommend and plan the installation ofnew systems or modifications of an existing system
# Ensuring that code is error free or has no bugs and test failure
# Preparing reports on programming project specifications,activities and status
# Ensure all the codes are raised as per the norm defined forproject / program / account with clear description and replicationpatterns
# Compile timely, comprehensive and accurate documentation andreports as requested
# Coordinating with the team on daily project status and progressand documenting it
# Providing feedback on usability and serviceability, trace theresult to quality risk and report it to concerned stakeholders
# Status Reporting and Customer Focus on an ongoing basis withrespect to project and its execution
# Capturing all the requirements and clarifications from theclient for better quality work
# Taking feedback on the regular basis to ensure smooth and ontime delivery
# Participating in continuing education and training to remaincurrent on best practices, learn new programming languages, and betterassist other team members.
# Consulting with engineering staff to evaluate software-hardwareinterfaces and develop specifications and performance requirements
# Document and demonstrate solutions by developing documentation,flowcharts, layouts, diagrams, charts, code comments and clear code
# Documenting very necessary details and reports in a formal wayfor proper understanding of software from client proposal toimplementation
# Ensure good quality of interaction with customer w.r.t. e-mailcontent, fault report tracking, voice calls, business etiquette etc
# Timely Response to customer requests and no instances ofcomplaints either internally or externally
#
# Stakeholder Interaction
#
# Stakeholder Type
#
# Stakeholder Identification
#
# Purpose of Interaction
#
# Internal
#
# Lead Software Developer and Project Manager
#
# Regular reporting & updates
#
# Software Developers
#
# For work coordination and support in providing testing solutions
#
# External
#
# Clients
#
# Provide apt solutions and support as per the requirement
#
#
#
#
#
# Display
#
# Lists the competencies required to perform this role effectively:
#
# Functional Competencies/ Skill
# Leveraging Technology – Knowledge of current and upcomingtechnology along with expertise in programming (automation, tools andsystems) to build efficiencies and effectiveness in own function/ Clientorganization – Competent
# Process Excellence - Ability to follow the standards and norms toproduce consistent results, provide effective control and reduction ofrisk – Expert
# Technical knowledge – knowledge of various programminglanguages, tools, quality management standards and processes - Expert
#
# Competency Levels
#
# Foundation
#
# Knowledgeable about the competency requirements. Demonstrates (inparts) frequently with minimal support and guidance.
#
# Competent
#
# Consistently demonstrates the full range of the competencywithout guidance. Extends the competency to difficult and unknownsituations as well.
#
# Expert
#
# Applies the competency in all situations and is serves as a guideto others as well.
#
# Master
#
# Coaches others and builds organizational capability in thecompetency area. Serves as a key resource for that competency and isrecognised within the entire organization.
#
#
#
#
#
# Behavioral Competencies
# Formulation & Prioritization
# Innovation
# Managing Complexity
# Execution Excellence
# Passion for Results
#
# Deliver
#
# No.
#
# Performance Parameter
#
# Measure
#
# Continuous Integration, Deployment & Monitoring of Software
#
# 100% error free on boarding & implementation, throughput %,Adherence to the schedule/ release plan
#
# Quality & CSAT
#
# On-Time Delivery, Manage software, Troubleshoot queries
#
# Customer experience, completion of assigned certifications for skillupgradation
#
# MIS & Reporting
#
# 100% on time MIS & report generation
#
# AI Cognitive
# Company Name : futuremug
# Job Title    : Python Developer Jr
# Location     : Kochi, Kerala, India
# Website URL  : https://in.linkedin.com/jobs/view/python-developer-jr-at-futuremug-3815797123?refId=3g2ulboN39fcvbOvldY2%2FA%3D%3D&trackingId=lPGsFsF%2BqQle2QyU8HqjwQ%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Job Description
#
# Role: : Python Developer
#
# Experience: 3+ years
#
# Location: Kochi
#
# Notice period: Immediate joiners
#
# Responsibilities
#
# Help design and implement functional requirements
# Build efficient back-end features in Python
# Integrate front-end components into applications
# Manage testing and bug fixes
# Prepare technical documentation
# Collaborate with UX/UI designers to implement design into the code
# Coach junior team members
# Implement software enhancements and suggest improvements
#
# Requirements
#
# Solid experience as Python Developer
# 3 years experience in design and programming large-scale applications through all phases of the software development life cycle including testing, implementation, and auditing
# 3 years of experience developing software using Python and the various tools in the Python ecosystem (pip, PyPI, virtualenv, pyenv, etc.)
# 1-year experience with SQL/NoSQL databases: MySQL, PostgreSQL, SQL Server, MongoDB, DynamoDB
# Ability to take ownership of assignments and drive to resolution
# Ability to work in a fast-paced, high-energy environment
# Experience with Python Django frameworks
